# %% [markdown]
# # Exploratory Data Analysis and Visualization <a class="tocSkip">

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span></li><li><span><a href="#Bad-Visualization" data-toc-modified-id="Bad-Visualization-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Bad Visualization</a></span></li><li><span><a href="#Good-Visualization" data-toc-modified-id="Good-Visualization-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Good Visualization</a></span></li><li><span><a href="#Six-categories-of-principles" data-toc-modified-id="Six-categories-of-principles-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Six categories of principles</a></span><ul class="toc-item"><li><span><a href="#Principles-of-Scale" data-toc-modified-id="Principles-of-Scale-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Principles of Scale</a></span></li><li><span><a href="#Principles-of-Conditioning" data-toc-modified-id="Principles-of-Conditioning-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Principles of Conditioning</a></span></li><li><span><a href="#Principles-of-Perception" data-toc-modified-id="Principles-of-Perception-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Principles of Perception</a></span><ul class="toc-item"><li><span><a href="#Color-perception" data-toc-modified-id="Color-perception-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Color perception</a></span></li><li><span><a href="#Area-vs-Length-perception" data-toc-modified-id="Area-vs-Length-perception-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Area vs Length perception</a></span></li><li><span><a href="#Moving-target" data-toc-modified-id="Moving-target-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Moving target</a></span></li></ul></li><li><span><a href="#Principles-of-Transformation" data-toc-modified-id="Principles-of-Transformation-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Principles of Transformation</a></span></li><li><span><a href="#Principles-of-Context" data-toc-modified-id="Principles-of-Context-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Principles of Context</a></span></li><li><span><a href="#Principles-of-Smoothing" data-toc-modified-id="Principles-of-Smoothing-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Principles of Smoothing</a></span><ul class="toc-item"><li><span><a href="#Gaussian-Kernel-Smoothing" data-toc-modified-id="Gaussian-Kernel-Smoothing-4.6.1"><span class="toc-item-num">4.6.1&nbsp;&nbsp;</span>Gaussian Kernel Smoothing</a></span></li><li><span><a href="#2-D-example:-Cherry-Blossom-Run-data" data-toc-modified-id="2-D-example:-Cherry-Blossom-Run-data-4.6.2"><span class="toc-item-num">4.6.2&nbsp;&nbsp;</span>2-D example: Cherry Blossom Run data</a></span></li><li><span><a href="#Two-dimensional-kernel-density-estimation" data-toc-modified-id="Two-dimensional-kernel-density-estimation-4.6.3"><span class="toc-item-num">4.6.3&nbsp;&nbsp;</span>Two dimensional kernel density estimation</a></span></li></ul></li></ul></li><li><span><a href="#Seaborn-visualization-documentaion" data-toc-modified-id="Seaborn-visualization-documentaion-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Seaborn visualization documentaion</a></span></li></ul></div>

# %% [markdown]
# ## Nonparametric Density Estimation (curve estimator)
#
# Density estimation is the problem of reconstructing the probability density function (PDF) using a set of given data
# points. Namely, we observe $D = \{x_1, \dots, x_n\}$ and we want to recover the underlying probability density function generating our dataset.
#
# **Curve estimator**: $\hat{f}(\cdot)$ is random because it is a function of the data.

# %% [markdown]
# ### Histogram estimator
#
# - To form a histogram estimator of a density $f$, we divide the real line to disjoint sets called **bins**, **binwidth** = $\frac{1}{m}$
#
# $$B_1 = \left[0, \frac{1}{m}\right), \; B_2 = \left[\frac{1}{m}, \frac{2}{m}\right), \; \dots, B_m = \left[\frac{m-1}{m}, \frac{m}{m}\right]$$
#
# - The **histogram estimator** $\hat f$ is a piecewise constant function (**discontinuous**) where the height of the function is proportional to number of observations in each bin, for a given data point $x \in B_j$,
#
# $$\widehat{f}_n(x) = \frac{\text{number of observations within } B_j}{n} \times \frac{1}{\text{length of the bin}} = \frac{m}{n} \sum_{i=1}^n \mathbb{I}(x_i \in B_j)$$
#
# $\implies$
# $$
# \begin{aligned}
# \mathbb{E}[\widehat{f}_n(x)] &= m \cdot \textrm{P}(x_i \in B_j) \\
# &= m \int_{B_j} f(u) du \\
# &= m \int_{\frac{j-1}{m}}^{\frac{j}{m}} f(u) du \\
# &= m \left(\textrm{F}\left(\frac{j}{m}\right) - \textrm{F}\left(\frac{j-1}{m}\right)\right) \\
# &= \frac{\left(\textrm{F}\left(\frac{j}{m}\right) - \textrm{F}\left(\frac{j-1}{m}\right)\right)}{\frac 1 m} \\
# & = f(x^*), \; x^* \in B_j \quad \text{mean value theorem}
# \end{aligned}
# $$
#
#
# - The number of bins controls the smoothing (balance betwen variance and bias):
#
#     - If we smooth too much (large bins), we get a highly biased estimator
#     - If we smooth too little (small bins), we get a highly variable estimator

# %% [markdown]
# <!---
# ![hist_bin](https://miro.medium.com/max/1400/1*q7Z4lgJmfSE1OAzmde-Nqw.png)
# [[Medium](https://medium.datadriveninvestor.com/how-to-decide-on-the-number-of-bins-of-a-histogram-3c36dc5b1cd8)]
# -->

# %% [markdown]
# ### Kernel Density Estimator (KDE)
#
# - Kernel density estimators are smoother and they converge faster to the true density than histograms
#
# - A **kernel** is defined to be any smooth function K such that $K(x) \geq 0, \; \int K(x) dx = 1, \; \int x K(x) dx = 0, \; \int x^2 K(x)dx = 1 (i.e., \text{Var}(x) = 1)$
#
# - Gaussian (Normal) kernel:
#
# $$ K(x) = (2\pi)^{-1/2} e ^{- \frac{x^2}{2}} $$
#
# - Given a kernel $K$ and a positive number $h$, called the **bandwidth**, the kernel density estimator is defined to be
#
#   $$ \hat{f}_n(x) = \frac{1}{n} \sum_{i=1}^n \frac{1}{h} K\left(\frac{x - x_i}{h} \right)$$ At each data point $x$, $\hat f_n(x)$ is the average of the kernels centered over the data points $x_i$
#
#
# -  The bandwidth $h$ controls the amount of smoothing
#     - When $h$ is close to 0, $\hat f_n$ consists of a set of spikes, one at each data point (undersmoothing, high variance)
#     - When $h$ $\rightarrow \infty$, $\hat f_n$ tends to a uniform density (oversmoothing, high bias)

# %% [markdown]
# <!---![KDE](images/kde.png) --->
# <td style="width: 50%;"> <img src="images/kde.png" alt="Drawing" style="width: 50%;"/>

# %% [markdown]
# ## Exploratory Data Analysis
#
# - John W. Tukey (1915-2000) was a mathematician

# %% [markdown]
# - Fast Fourier Transform (Cooley-Tukey algorithm)

# %% [markdown]
# - Coined the phrase Exploratory Data Analysis (EDA)
#     ![EDA book](images/john-tukey.jpg)

# %% [markdown]
# ![EDA book](images/eda-book.jpg)

# %% [markdown]
# > 'Exploratory data analysis' is an attitude, a state of flexibility, a willingness to look for those things that we believe are not there, as well as those we believe to be there. - Exploratory Data Analysis

# %% [markdown]
# > If we need a short suggestion of what exploratory data analysis is, I would suggest that: 1. it is an attitude, AND 2. a flexibility, AND 3. some graph paper (or transparencies, or both). - The collected works of John W. Tukey: Philosophy and principles of data analysis

# %% [markdown]
# ### EDA should involve lots of visualization<a class="tocSkip">

# %% [markdown]
# ## Bad Visualization
#
# ![(3D) pie charts](https://www.designyourway.net/diverse/2/wronginfo/60203066686.jpg)

# %% [markdown]
# ![3D bar chart](https://static1.squarespace.com/static/55e61d62e4b0df4b0ce3dc61/t/58d466856a49630cabcb8807/1490314890663/3dbar.png)![image.png](attachment:image.png)

# %% [markdown]
# ![No axis labels](https://www.statschat.org.nz/wp-content/uploads/2013/09/iphone-sales.jpg)

# %% [markdown]
# ![inconsistent axis](http://cs.colby.edu/courses/S14/cs251/LectureNotes/figures/developer_skills.jpg)

# %% [markdown]
# ![Catchy graphics](https://www.statschat.org.nz/wp-content/uploads/2011/09/infographic-bad-laundry.png)

# %% [markdown]
# ![Hmmmm](https://www.designyourway.net/diverse/2/wronginfo/59790878184.jpg)

# %% [markdown]
# [Bad visualizations](https://www.google.com/search?q=bad+visualizations&source=lnms&tbm=isch&sa=X&ved=0ahUKEwiU2fG8qtnhAhXIna0KHXfsALkQ_AUIDigB&biw=1744&bih=1863)
#
# [WTF Visualizations](http://viz.wtf/)

# %% [markdown]
# ## Good Visualization
#
# - [Gapminder Example](https://www.gapminder.org/tools/#$state$time$value=2018;&marker$axis_x$scaleType=linear;;;&chart-type=bubbles)

# %% [markdown]
# - Interactivity

# %% [markdown]
# - Good use of color, shapes, and sizes

# %% [markdown]
# - Clear labeling of components

# %% [markdown]
# - Axis (log vs. linear)

# %% [markdown]
# ## Six categories of principles
#
# - scale
# - conditioning
# - perception
# - transformation
# - context
# - smoothing
#
# [Berkeley's DS-100 textbook](http://www.ds100.org)

# %% [markdown]
# ### Principles of Scale
#
# - Representative Chaffetz discussed in a congressional hearing [[full report](https://oversight.house.gov/interactivepage/plannedparenthood.)]

# %% [markdown]
# - Two numbers from Planned Parenthood programs:

# %% [markdown]
# - Number of abortions and cancer screenings
#     ![viz_planned_parenthood.png](images/viz_planned_parenthood.png)

# %% [markdown]
# - In reality the plot looked like this:

# %%
# HIDDEN
import warnings
# Ignore numpy dtype warnings. These warnings are caused by an interaction
# between numpy and Cython and can be safely ignored.
# Reference: https://stackoverflow.com/a/40846742
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual

sns.set()
sns.set_context('talk')
np.set_printoptions(threshold=20, precision=2, suppress=True)
pd.options.display.max_rows = 7
pd.options.display.max_columns = 8
pd.set_option('precision', 2)
# This option stops scientific notation for pandas
# pd.set_option('display.float_format', '{:.2f}'.format)

pp = pd.read_csv("data/plannedparenthood.csv")
plt.plot(pp['year'], pp['screening'], linestyle="solid", marker="o", label='Cancer')
plt.plot(pp['year'], pp['abortion'], linestyle="solid", marker="o", label='Abortion')
plt.title('Planned Parenthood Procedures')
plt.xlabel("Year")
plt.ylabel("Service")
plt.xticks([2006, 2013])
plt.legend();

# %% [markdown]
# - Zoom to appropriate scale
#
# ![viz_zoom.png](images/viz_zoom.png)

# %% [markdown]
# ### Principles of Conditioning
#
# - The US Bureau of Labor Statistics oversees scientific surveys related to the economic health of the US

# %% [markdown]
# - Following compares median weekly earnings split by sex: [US Bureau of Labor Statistics](https://www.bls.gov/data/)

# %% [markdown]
# - ![viz_earnings.png](images/viz_earnings.png)

# %% [markdown]
# - Comparison between Men and Women are easier (wage gap)
#
# - Lines are usually appropriate for ordinal and numerical data

# %%
cps = pd.read_csv("data/edInc2.csv")
ax = sns.pointplot(x="educ", y="income", hue="gender", data=cps)

ticks = ["<HS", "HS", "<BA", "BA", ">BA"]
ax.set_xticklabels(ticks)
ax.set_xlabel("Education")
ax.set_ylabel("Income")
ax.set_title("2014 Median Weekly Earnings\nFull-Time Workers over 25 years old");

# %% [markdown]
# ### Principles of Perception
#
# #### Color perception
#
# - Humans perceive colors differently

# %% [markdown]
# ![checker-shadow.svg](https://upload.wikimedia.org/wikipedia/commons/b/be/Checker_shadow_illusion.svg)

# %% [markdown]
# ![checker-shadow2.svg](https://upload.wikimedia.org/wikipedia/commons/2/21/Grey_square_optical_illusion_proof2.svg)
#
# [Web color 787877](https://www.color-hex.com/color/787877)
# [Checker Shadow illusion](https://en.wikipedia.org/wiki/Checker_shadow_illusion)

# %% [markdown]
# - Not good!
#     ![viz_earnings.png](images/viz_earnings.png)

# %% [markdown]
# - Qualitative colors:

# %%
import seaborn as sns

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.palplot(sns.color_palette())

# %% [markdown]
# - Circular colors:

# %%
sns.palplot(sns.color_palette("husl", 8))

# %% [markdown]
# - Color Brewer interactive color chooser:

# %%
#temp = sns.choose_colorbrewer_palette("diverging")
temp = sns.choose_colorbrewer_palette("sequential")
# Out:
# interactive(children=(Dropdown(description='name', options=('Greys', 'Reds', 'Greens', 'Blues', 'Oranges', 'Pu…

# %%
temp
# Out:
# [(0.9971703191080351, 0.9013610149942332, 0.8562860438292966),
#  (0.9926028450595925, 0.8141330257593233, 0.7383775470972702),
#  (0.9882352941176471, 0.7068512110726642, 0.6010149942329872),
#  (0.988235294117647, 0.5857900807381776, 0.46223760092272215),
#  (0.9857285659361784, 0.47227989234909656, 0.34678969627066525),
#  (0.9673356401384082, 0.349188773548635, 0.24775086505190302),
#  (0.9256286043829295, 0.2200692041522493, 0.16770472895040378),
#  (0.8193310265282583, 0.11672433679354088, 0.12341407151095724),
#  (0.7130949634755863, 0.07446366782006919, 0.09625528642829641),
#  (0.579361783929258, 0.04244521337946949, 0.07361783929257926)]

# %%
sns.palplot(sns.color_palette(temp))

# %% [markdown]
# - Color pallette from color names: e.g., [xkcd colors](https://xkcd.com/color/rgb/)

# %%
colors = ["puke green", "pistachio", "bubblegum pink", "mud brown", "ugly yellow", "dusty purple"]
sns.palplot(sns.xkcd_palette(colors))

# %% [markdown]
# - Some sequential colors can be used as `colormaps`:  e.g., `cubehelix_palette()`

# %%
x, y = np.random.multivariate_normal([0, 0], [[1, -.5], [-.5, 1]], size=300).T
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
sns.kdeplot(x, y, cmap=cmap, shade=True);

# %% [markdown]
# - Diverging colors:

# %%
sns.palplot(sns.color_palette("coolwarm", 7))

# %% [markdown]
# - [NYTimes Middle-class Jobs visualization](https://www.nytimes.com/interactive/2015/02/23/business/economy/the-changing-nature-of-middle-class-jobs.html)

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

sns.set_palette("husl")
sinplot()

# %%
with sns.color_palette("PuBuGn_d"):
    sinplot()

# %% [markdown]
# #### Area vs Length perception
#
# - Human's perception of lengths is better than areas
#
# - South Africa is about twice that of Algeria
#
# ![viz_gdp.png](images/viz_gdp_v2.png)

# %% [markdown]
# - South Africa is about twice that of Algeria
#
# ![viz_gdp.png](images/viz_gdp.png)

# %% [markdown]
# #### Moving target
#
# - Human eyes do not detect changing baseline well
#
# - Carbon dioxide emissions over time split by country.
#
# ![images/viz_emissions.png](images/viz_emissions.png)

# %% [markdown]
# - Does UK's emissions have increased or decreased over time?
#
# - Changing baseline makes it difficult to see

# %% [markdown]
# ![images/viz_bar_stacked.jpeg](images/viz_bar_stacked.jpeg)

# %%
co2 = pd.read_csv("data/CAITcountryCO2.csv", skiprows = 2,
                  names = ["Country", "Year", "CO2"])
last_year = co2.Year.iloc[-1]
q = f"Country != 'World' and Country != 'European Union (15)' and Year == {last_year}"
top14_lasty = co2.query(q).sort_values('CO2', ascending=False).iloc[:14]
top14 = co2[co2.Country.isin(top14_lasty.Country) & (co2.Year >= 1950)]

from cycler import cycler

linestyles = (['-', '--', ':', '-.']*3)[:7]
colors = sns.color_palette('colorblind')[:4]
lines_c = cycler('linestyle', linestyles)
color_c = cycler('color', colors)

fig, ax = plt.subplots(figsize=(9, 9))
ax.set_prop_cycle(lines_c * color_c)

x, y ='Year', 'CO2'
for name, df in top14.groupby('Country'):
    ax.semilogy(df[x], df[y], label=name)

ax.set_xlabel(x)
ax.set_ylabel(y + "Emissions [Million Tons]")
ax.legend(ncol=2, frameon=True);

# %% [markdown]
# ### Principles of Transformation
#
# - Data transformation reveal non-linear relationships between variables
#
# - Distribution of ticket fares on Titanic is right-skewed (right-tailed)

# %% [markdown]
# $Y = X\beta + \epsilon$
# $log(Y) = X\beta + \epsilon$
#
# Y: time postive,
#
# Y -> log(Y)

# %%
sns.set_palette(sns.color_palette("muted"))

ti = sns.load_dataset('titanic')
sns.distplot(ti['fare'])
plt.title('Fares for Titanic Passengers')
plt.xlabel('Fare in USD')
plt.ylabel('Density');

# %%
sns.distplot(np.log(ti.loc[ti['fare'] > 0, 'fare']), bins=25)
plt.title('log(Fares) for Titanic Passengers')
plt.xlabel('log(Fare) in USD')
plt.ylabel('Density');

# %% [markdown]
# Advantadges to do log transformation:
#
# - outliers, normalize the data to a reasonable range
# - $x \in [0,1], -\infty< log(x)< \infty$

# %% [markdown]
# - Kepler recorded planets distances to the sun and their periods of orbit

# %% [markdown]
# - Basis for Third Law of Planetary Motion

# %%
planets = pd.read_csv("data/planets.data", delim_whitespace=True, comment="#", usecols=[0, 1, 2])
planets
# Out:
#     planet  mean_dist    period
# 0  Mercury       0.39     87.77
# 1    Venus       0.72    224.70
# 2    Earth       1.00    365.25
# 3     Mars       1.52    686.95
# 4  Jupiter       5.20   4332.62
# 5   Saturn       9.51  10759.20

# %%
sns.lmplot(x='mean_dist', y='period', data=planets, ci=False);

# %%
sns.lmplot(x='mean_dist', y='period',
           data=np.log(planets.iloc[:, [1, 2]]),
           ci=False);

# %% [markdown]
# $$
# \begin{aligned}
# \log(period) &= m \log(dist) + b \\
# period &= e^{m \log(dist) + b} & \text{Taking the exponent of both sides} \\
# period &= e^b dist^m \\
# period &= C \cdot dist^m
# \end{aligned}
# $$
#
# - Constant $ C = e^b $

# %% [markdown]
# - Two variables have a polynomial relationship, so log of the variables are linearly related

# %% [markdown]
# - Degree of the polynomial is slope of the line

# %% [markdown]
# - Slope is 1.5 which gives us Kepler's third law: $ period \propto dist^{1.5} $

# %% [markdown]
# - Similarly, if $ \log(y) $ and $ x $ have linear dependence, $x$ and $y$ have exponential relationship: $ y = a^x $

# %% [markdown]
# ### Principles of Context
#
# - Add as much relevant context as possible

# %% [markdown]
# - Following shows provides little context of what is being plotted
#
# ![images/viz_538_before.png](images/viz_538_before.png)

# %% [markdown]
# - Plots can be self-explanatory

# %% [markdown]
# - Add title, caption, axes labels, units for the axes, and labels for the plotted lines
#
# ![images/viz_538_after.png](images/viz_538_after.png)

# %% [markdown]
# ([This blog post](https://www.dataquest.io/blog/making-538-plots/) explains how to make these modifications using `matplotlib`.)
#
# In general, we provide context for a plot through:
#
# - Plot title
# - Axes labels
# - Reference lines and markers for important values
# - Labels for interesting points and unusual observations
# - Captions that describe the data and its important features

# %% [markdown]
# ### Principles of Smoothing
#
# - Smoothing can help when there are many data points
#
# - Histograms are a type of smoothing for rugplots: e.g. age of the passengers in the Titanic.

# %%
ages = ti['age'].dropna()
sns.rugplot(ages, height=0.2);

# %% [markdown]
# - Histogram is helpful and _kernel density estimation_ (KDE) can be useful

# %%
sns.distplot(ages, kde=True); # defaults to adding smoothing

# %% [markdown]
# #### Gaussian Kernel Smoothing

# %%
points = np.array([2, 3, 5])
sns.rugplot(points, height=0.2)
plt.xlim(0, 7);

# %%
from scipy.stats import norm

def gaussians(points, scale=True, sd=0.5):
    x_vals = [np.linspace(point - 2, point + 2, 100) for point in points]
    y_vals = [norm.pdf(xs, loc=point, scale=sd) for xs, point in zip(x_vals, points)]
    if scale:
        y_vals = [ys / len(points) for ys in y_vals]
    return zip(x_vals, y_vals)

for xs, ys in gaussians(points, scale=True):
    plt.plot(xs, ys, c=sns.color_palette()[0])

sns.rugplot(points, height=0.2)
plt.xlim(0, 7)
plt.ylim(0, 1);

# %%
sns.rugplot(points, height=0.2)
sns.kdeplot(points, bw=0.5)
plt.xlim(0, 7)
plt.ylim(0, 1);

# %%
sns.kdeplot(ages)
sns.rugplot(ages);

# %%
sns.kdeplot(ages, bw=0.5) # narrower Gaussian results in less smoothing
sns.rugplot(ages);

# %% [markdown]
# #### 2-D example: Cherry Blossom Run data
#
# - Annual 10-mile run in Washington D.C.

# %% [markdown]
# - Each runner can report their age and their race time

# %%
import pandas as pd

# %%
runners = pd.read_csv('data/cherryBlossomMen.csv').dropna()
runners
# Out:
#        year  place   age    time
# 0      1999      1  28.0  2819.0
# 1      1999      2  24.0  2821.0
# 2      1999      3  27.0  2823.0
# 3      1999      4  28.0  2827.0
# 4      1999      5  26.0  2851.0
# ...     ...    ...   ...     ...
# 70064  2012   7188  41.0  8807.0
# 70065  2012   7189  39.0  8831.0
# 70066  2012   7190  56.0  8840.0
# 70067  2012   7191  35.0  8850.0
# 70069  2012   7193  48.0  9059.0
#
# [70045 rows x 4 columns]

# %%
sns.lmplot(x='age', y='time', data=runners, fit_reg=False);

# %% [markdown]
# - Many points make it difficult to see any trend

# %% [markdown]
# - Two dimensional kernel smoothing!

# %% [markdown]
# #### Two dimensional kernel density estimation

# %%
# Plot three points
two_d_points = pd.DataFrame({'x': [1, 3, 4], 'y': [4, 3, 1]})
sns.lmplot(x='x', y='y', data=two_d_points, fit_reg=False)
plt.xlim(-2, 7)
plt.ylim(-2, 7);

# %%
# Place a Gaussian at each point and use a contour plot to show each one
sns.kdeplot(two_d_points['x'], two_d_points['y'], bw=0.4)
plt.xlim(-2, 7)
plt.ylim(-2, 7);

# %%
# Place a Gaussian at each point and use a contour plot to show each one
sns.kdeplot(two_d_points['x'], two_d_points['y'])
plt.xlim(-2, 7)
plt.ylim(-2, 7);

# %%
sns.kdeplot(runners['age'], runners['time'])
plt.xlim(-10, 70)
plt.ylim(3000, 8000);

# %% [markdown]
# - Most runners were between 25 and 50

# %% [markdown]
# - Most ran between 1 to 2 hours (4000-7000 seconds)

# %% [markdown]
# - Slight up-trend as age increases?

# %% [markdown]
# - Strange group of age between 0 and 10 years old

# %% [markdown]
# ## Seaborn visualization documentaion
#
# - Relational: [API](https://seaborn.pydata.org/api.html#relational-api) / [Tutorial](https://seaborn.pydata.org/tutorial/relational.html#relational-tutorial)
# - Categorical: [API](https://seaborn.pydata.org/api.html#categorical-api) / [Tutorial](https://seaborn.pydata.org/tutorial/categorical.html#categorical-tutorial)
# - Distributions: [API](https://seaborn.pydata.org/api.html#distribution-api) / [Tutorial](https://seaborn.pydata.org/tutorial/distributions.html#distribution-tutorial)
# - Regressions: [API](https://seaborn.pydata.org/api.html#regression-api) / [Tutorial](https://seaborn.pydata.org/tutorial/regression.html#regression-tutorial)
# - Multiples: [API](https://seaborn.pydata.org/api.html#grid-api) / [Tutorial](https://seaborn.pydata.org/tutorial/axis_grids.html#grid-tutorial)
# - Style: [API](https://seaborn.pydata.org/api.html#style-api) / [Tutorial](https://seaborn.pydata.org/tutorial/aesthetics.html#aesthetics-tutorial)
# - Color: [API](https://seaborn.pydata.org/api.html#palette-api) / [Tutorial](https://seaborn.pydata.org/tutorial/color_palettes.html#palette-tutorial)
